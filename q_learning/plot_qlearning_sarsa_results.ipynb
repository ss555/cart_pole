# %%
import pandas as pd
pd.options.plotting.backend = "plotly"
import numpy as np
import os
from pathlib import Path
from numba import njit
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /usr/lib/python3/dist-packages/pandas/core/config_init.py in register_plotting_backend_cb(key)
#     603     try:
# --> 604         importlib.import_module(backend_str)
#     605     except ImportError:
#
# /usr/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /usr/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'plotly'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-1-fc7e16a9763b> in <module>
#       1 import pandas as pd
# ----> 2 pd.options.plotting.backend = "plotly"
#       3 import numpy as np
#       4 import os
#       5 from pathlib import Path
#
# /usr/lib/python3/dist-packages/pandas/_config/config.py in __setattr__(self, key, val)
#     194         # can you can't overwrite subtrees
#     195         if key in self.d and not isinstance(self.d[key], dict):
# --> 196             _set_option(prefix, val)
#     197         else:
#     198             raise OptionError("You can only set the value of existing options")
#
# /usr/lib/python3/dist-packages/pandas/_config/config.py in _set_option(*args, **kwargs)
#     136                     o.cb(key)
#     137             else:
# --> 138                 o.cb(key)
#     139
#     140
#
# /usr/lib/python3/dist-packages/pandas/core/config_init.py in register_plotting_backend_cb(key)
#     604         importlib.import_module(backend_str)
#     605     except ImportError:
# --> 606         raise ValueError(
#     607             '"{}" does not seem to be an installed module. '
#     608             "A pandas plotting backend must be a module that "
#
# ValueError: "plotly" does not seem to be an installed module. A pandas plotting backend must be a module that can be imported

# %%
path = Path('/home/robotfish/Project/cart_pole/q_learning/0525_113819')
csvfiles = list(path.glob('**/ql_*.csv'))


def plotResult(file):
    os.chdir(file.parent)
    df = pd.read_csv(file)
    df['reward_roll'] = df.reward.rolling(1000).mean()
    df['eps_normalized'] = df['eps']*df.reward.max()
    fig = df.plot(y=['reward_roll', 'eps_normalized'],)
    fig.write_html(file.stem+'_plot.html')

#list(map(plotResult, csvfiles))

# %%
path = Path('/home/robotfish/Project/cart_pole/q_learning/0525_113819')
csvfiles = list(path.glob('*.out'))
# print(list(csvfiles))

def plotResult(file):
    os.chdir(file.parent)
    df = pd.read_csv(file, header=None)
    df['reward_roll'] = df[2].rolling(10).mean()
    # df['eps_normalized'] = df[1]*df[2].max()
    fig = df.plot(y=['reward_roll'], title=file.stem)
    fig.show()
    fig.write_html(file.stem+'_plot.html')

list(map(plotResult, csvfiles))
